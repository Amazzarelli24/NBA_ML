# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import AdaBoostClassifier
from sklearn import datasets
# Import train_test_split function
from sklearn.model_selection import train_test_split
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# %%
champ_data = pd.read_csv('/content/champ_data.csv')

# %%
champ_data.head()
# Out:
#                                              team_id  season  \
# 0  https://www.basketball-reference.com/teams/MIA...    2023
# 1  https://www.basketball-reference.com/teams/POR...    2023
# 2  https://www.basketball-reference.com/teams/SAC...    2023
# 3  https://www.basketball-reference.com/teams/BOS...    2023
# 4  https://www.basketball-reference.com/teams/GSW...    2023
#
#                      name  champion conference    FG   FGA    FG%    3P   3PA  \
# 0              Miami Heat     False       East  39.1  85.3  0.459  11.9  34.7
# 1  Portland Trail Blazers     False       West  40.5  85.3  0.475  12.9  35.3
# 2        Sacramento Kings     False       West  43.7  88.2  0.495  13.8  37.2
# 3          Boston Celtics     False       East  42.2  88.8  0.475  15.9  42.4
# 4   Golden State Warriors     False       West  43.0  90.1  0.477  16.5  43.1
#
#    ...    L1YP    L3YP    L6YP  L10YP  count_playoff_games  count_champion  \
# ...

# %%
champ_data = champ_data[champ_data["season"] > 2000]
champ_data = champ_data[champ_data["season"]<2023]

# %%
conferences = np.unique(champ_data["conference"])

# %%
change = LabelEncoder()
confernce_labels = change.fit_transform(champ_data["conference"])
conference_mappings = {index: label for index, label in
                  enumerate(change.classes_)}

# %%
champ_data["conference"] = confernce_labels
champ_data[["team_id","season","name","champion","conference"]].iloc[1:6]
# Out:
#                                               team_id  season  \
# 31  https://www.basketball-reference.com/teams/ATL...    2022
# 32  https://www.basketball-reference.com/teams/UTA...    2022
# 33  https://www.basketball-reference.com/teams/BOS...    2022
# 34  https://www.basketball-reference.com/teams/IND...    2022
# 35  https://www.basketball-reference.com/teams/GSW...    2022
#
#                      name  champion  conference
# 31          Atlanta Hawks     False           0
# 32              Utah Jazz     False           1
# 33         Boston Celtics     False           0
# 34         Indiana Pacers     False           0
# 35  Golden State Warriors      True           1

# %%
bandana = LabelEncoder()
champion_labels = bandana.fit_transform(champ_data["champion"])
champion_mappings = {index: label for index, label in
                  enumerate(bandana.classes_)}

# %%
champ_data["champion"] = champion_labels
champ_data[["team_id","season","name","champion","conference"]].iloc[1:6]
# Out:
#                                               team_id  season  \
# 31  https://www.basketball-reference.com/teams/ATL...    2022
# 32  https://www.basketball-reference.com/teams/UTA...    2022
# 33  https://www.basketball-reference.com/teams/BOS...    2022
# 34  https://www.basketball-reference.com/teams/IND...    2022
# 35  https://www.basketball-reference.com/teams/GSW...    2022
#
#                      name  champion  conference
# 31          Atlanta Hawks         0           0
# 32              Utah Jazz         0           1
# 33         Boston Celtics         0           0
# 34         Indiana Pacers         0           0
# 35  Golden State Warriors         1           1

# %%
fork = LabelEncoder()
Playoff_labels = fork.fit_transform(champ_data["Playoff"])
Playoff_mappings = {index: label for index, label in
                  enumerate(fork.classes_)}

# %%
champ_data["Playoff"] = Playoff_labels
champ_data[["First_4_Months","Last_4_Months","Playoff"]].iloc[1:7]
# Out:
#     First_4_Months  Last_4_Months  Playoff
# 31        0.480000       0.574468        1
# 32        0.588235       0.489362        1
# 33        0.519231       0.739130        1
# 34        0.365385       0.239130        0
# 35        0.745098       0.541667        1
# 36        0.306122       0.234043        0

# %%
if "team_id" in champ_data.columns:
  champ_data.drop(["team_id","name"],axis=1,inplace=True)

# %%
champ_data.head()
# Out:
#     season  champion  conference    FG   FGA    FG%    3P   3PA    3P%    2P  \
# 30    2022         0           0  38.3  88.3  0.434  12.2  36.9  0.331  26.1
# 31    2022         0           0  41.5  88.3  0.470  12.9  34.4  0.374  28.6
# 32    2022         0           1  40.6  86.2  0.471  14.5  40.3  0.360  26.0
# 33    2022         0           0  40.7  87.4  0.466  13.2  37.1  0.356  27.5
# 34    2022         0           0  41.4  89.5  0.463  12.2  35.4  0.344  29.3
#
#     ...    L1YP   L3YP    L6YP   L10YP  count_playoff_games  count_champion  \
# 30  ...  0.0000  0.125  0.1250  0.1875                  0.0             0.0
# 31  ...  0.6250  0.625  1.0000  1.9375                271.0             0.0
# 32  ...  0.3750  0.625  1.1875  1.1875                296.0             0.0
# 33  ...  0.0625  1.000  2.3750  3.1875                398.0             0.0
# 34  ...  0.0000  0.000  0.3750  2.0625                  0.0             0.0
#
# ...

# %%
years = [2000,2014,2023]
values = [0,1]
champ_data["rule_change"]=pd.cut(champ_data["season"],bins=years,labels=values,right=False)
champ_data["rule_change"]=pd.to_numeric(champ_data["rule_change"])
champ_data.tail()
# Out:
#      season  champion  conference    FG   FGA    FG%   3P   3PA    3P%    2P  \
# 681    2001         0           1  35.3  78.9  0.448  4.4  13.0  0.339  30.9
# 682    2001         0           1  35.9  82.4  0.436  4.0  12.9  0.315  31.9
# 683    2001         0           0  36.7  83.8  0.438  6.0  16.4  0.364  30.8
# 684    2001         0           1  35.9  79.2  0.453  6.1  17.2  0.357  29.7
# 685    2001         0           1  38.2  85.0  0.449  5.8  16.5  0.354  32.4
#
#      ...      L3YP      L6YP     L10YP  count_playoff_games  count_champion  \
# 681  ...  0.000000  0.000000  0.266667                  0.0             0.0
# 682  ...  0.333333  0.933333  2.533333                396.0             3.0
# 683  ...  0.066667  1.400000  1.400000                 76.0             0.0
# 684  ...  0.200000  2.000000  3.400000                  0.0             0.0
# 685  ...  0.266667  0.333333  0.333333                167.0             0.0
#
# ...

# %%
champ_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 656 entries, 30 to 685
# Data columns (total 93 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       656 non-null    int64
#  1   champion                     656 non-null    int64
#  2   conference                   656 non-null    int64
#  3   FG                           656 non-null    float64
#  4   FGA                          656 non-null    float64
#  5   FG%                          656 non-null    float64
#  6   3P                           656 non-null    float64
#  7   3PA                          656 non-null    float64
#  8   3P%                          656 non-null    float64
#  9   2P                           656 non-null    float64
#  10  2PA                          656 non-null    float64
#  11  2P%                          656 non-null    float64
# ...

# %%
if "season" in champ_data:
  champ_data.drop(["season"],axis=1,inplace=True)

# %%
champ_data["percent_from_3"] = (champ_data["3PA"]/champ_data["FGA"])*100
champ_data.head()
# Out:
#     champion  conference    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 30         0           0  38.3  88.3  0.434  12.2  36.9  0.331  26.1  51.4
# 31         0           0  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9
# 32         0           1  40.6  86.2  0.471  14.5  40.3  0.360  26.0  45.8
# 33         0           0  40.7  87.4  0.466  13.2  37.1  0.356  27.5  50.3
# 34         0           0  41.4  89.5  0.463  12.2  35.4  0.344  29.3  54.1
#
#     ...    L6YP   L10YP  count_playoff_games  count_champion  sum_mvp_shares  \
# 30  ...  0.1250  0.1875                  0.0             0.0           0.000
# 31  ...  1.0000  1.9375                271.0             0.0           0.000
# 32  ...  1.1875  1.1875                296.0             0.0           0.010
# 33  ...  2.3750  3.1875                398.0             0.0           0.001
# 34  ...  0.3750  2.0625                  0.0             0.0           0.000
#
# ...

# %%
champ_data["percent_from_2"] = (champ_data["2PA"]/champ_data["FGA"])*100
champ_data.head()
# Out:
#     champion  conference    FG   FGA    FG%    3P   3PA    3P%    2P   2PA  \
# 30         0           0  38.3  88.3  0.434  12.2  36.9  0.331  26.1  51.4
# 31         0           0  41.5  88.3  0.470  12.9  34.4  0.374  28.6  53.9
# 32         0           1  40.6  86.2  0.471  14.5  40.3  0.360  26.0  45.8
# 33         0           0  40.7  87.4  0.466  13.2  37.1  0.356  27.5  50.3
# 34         0           0  41.4  89.5  0.463  12.2  35.4  0.344  29.3  54.1
#
#     ...   L10YP  count_playoff_games  count_champion  sum_mvp_shares  \
# 30  ...  0.1875                  0.0             0.0           0.000
# 31  ...  1.9375                271.0             0.0           0.000
# 32  ...  1.1875                296.0             0.0           0.010
# 33  ...  3.1875                398.0             0.0           0.001
# 34  ...  2.0625                  0.0             0.0           0.000
#
#     sum_dpoy_shares  count_all_nba  count_all_defensive  rule_change  \
# ...

# %%
X = champ_data[["3P","3PA","3P%","DRtg", "Defense Four Factors|eFG%", "Defense Four Factors|TOV%", "Defense Four Factors|DRB%", "Defense Four Factors|FT/FGA", "rule_change","champion","Playoff","ORtg","percent_from_3","sum_mvp_shares", "sum_dpoy_shares", "count_all_nba","count_all_defensive","2PA","2P%","percent_from_2","sum_mvp_shares", "count_all_nba","count_playoff_games", "L1YP","L3YP","L6YP","SRS", "MOV","ORtg","Offense Four Factors|eFG%","Offense Four Factors|TOV%","Offense Four Factors|ORB%","Offense Four Factors|FT/FGA"]]
X.head()
# Out:
#       3P   3PA    3P%   DRtg  Defense Four Factors|eFG%  \
# 30  12.2  36.9  0.331  112.5                      0.532
# 31  12.9  34.4  0.374  114.9                      0.543
# 32  14.5  40.3  0.360  110.5                      0.521
# 33  13.2  37.1  0.356  106.9                      0.502
# 34  12.2  35.4  0.344  116.1                      0.552
#
#     Defense Four Factors|TOV%  Defense Four Factors|DRB%  \
# 30                       11.7                       77.2
# 31                       11.5                       76.9
# 32                       10.9                       78.3
# 33                       12.5                       77.3
# 34                       11.9                       76.2
#
#     Defense Four Factors|FT/FGA  rule_change  champion  ...    L1YP   L3YP  \
# 30                        0.196            1         0  ...  0.0000  0.125
# 31                        0.177            1         0  ...  0.6250  0.625
# ...

# %%
X0 = X[X["rule_change"] == 0]
X1 = X[X["rule_change"] == 1]

# %% [markdown]
# ###Three Point Shooting vs Defensive Rating (2014-2022)

# %%
x = X1[["3PA","3P%","percent_from_3"]]
y = X1["DRtg"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

model = linear_model.LinearRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print("m is", model.coef_)
print("mean absolute error:",mean_absolute_error(y_test, y_pred))
print("r2_score:",r2_score(y_test,y_pred))
print("mean_squared_error:",mean_squared_error(y_test,y_pred))
# Out:
# m is [  1.21070284 -26.75040991  -0.87498556]
# mean absolute error: 2.485436482098309
# r2_score: 0.23380243616673735
# mean_squared_error: 8.805240779555357

# %% [markdown]
# ###Three Point Shooting vs Defensive Rating (2001-2013)

# %%
x = X0[["3PA","3P%","percent_from_3"]]
y = X0["DRtg"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

model = linear_model.LinearRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print("m is", model.coef_)
print("mean absolute error:",mean_absolute_error(y_test, y_pred))
print("r2_score:",r2_score(y_test,y_pred))
print("mean_squared_error:",mean_squared_error(y_test,y_pred))
# Out:
# m is [  1.8375673  -17.54125386  -1.39910077]
# mean absolute error: 2.455796627914836
# r2_score: 0.13928417107093505
# mean_squared_error: 9.642429641846375

# %% [markdown]
# ###Team Offense vs Team Defense (2014-2022)

# %%
x = X1[["ORtg","Offense Four Factors|eFG%","Offense Four Factors|TOV%","Offense Four Factors|ORB%","Offense Four Factors|FT/FGA"]]
y = X1["DRtg"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

model = linear_model.LinearRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print("m is", model.coef_)
print("mean absolute error:",mean_absolute_error(y_test, y_pred))
print("r2_score:",r2_score(y_test,y_pred))
print("mean_squared_error:",mean_squared_error(y_test,y_pred))
# Out:
# m is [   0.9886039     0.9886039  -299.50370661    2.3864961    -1.05868855
#   -79.21245449]
# mean absolute error: 2.5651057560274104
# r2_score: 0.15896310458210205
# mean_squared_error: 9.665303987126583

# %% [markdown]
# ###Team Offense vs Team Defense (2001-2013)

# %%
x = X0[["ORtg","Offense Four Factors|eFG%","Offense Four Factors|TOV%","Offense Four Factors|ORB%","Offense Four Factors|FT/FGA"]]
y = X0["DRtg"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

model = linear_model.LinearRegression()

model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print("m is", model.coef_)
print("mean absolute error:",mean_absolute_error(y_test, y_pred))
print("r2_score:",r2_score(y_test,y_pred))
print("mean_squared_error:",mean_squared_error(y_test,y_pred))
# Out:
# m is [   1.17824652    1.17824652 -337.89865276    3.45958375   -1.10840827
#   -74.64680839]
# mean absolute error: 2.622193195741579
# r2_score: 0.04197979232321092
# mean_squared_error: 10.73251140214804

# %% [markdown]
# ###3 Point Shooting vs Playoffs (2014-2022)

# %%
x = X1[["3PA","3P%","percent_from_3"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.5777777777777777
# precision: 0.5138888888888888
# recall: 0.925
# f1_score: 0.6607142857142857
#               precision    recall  f1-score   support
#
#            0     0.8333    0.3000    0.4412        50
#            1     0.5139    0.9250    0.6607        40
#
#     accuracy                         0.5778        90
#    macro avg     0.6736    0.6125    0.5509        90
# weighted avg     0.6914    0.5778    0.5387        90

# %%
x = X1[["3PA","3P%","percent_from_3"]]
y = X1["Playoff"]

x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.3, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.6296296296296297
# precision: 0.5833333333333334
# recall: 0.5833333333333334
# f1_score: 0.5833333333333334
#               precision    recall  f1-score   support
#
#            0     0.6667    0.6667    0.6667        45
#            1     0.5833    0.5833    0.5833        36
#
#     accuracy                         0.6296        81
#    macro avg     0.6250    0.6250    0.6250        81
# weighted avg     0.6296    0.6296    0.6296        81

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# ###3 Point Shooting vs Playoffs (2001-2013)

# %%
x = X0[["3PA","3P%","percent_from_3"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.6640625
# precision: 0.7
# recall: 0.6901408450704225
# f1_score: 0.6950354609929078
#               precision    recall  f1-score   support
#
#            0     0.6207    0.6316    0.6261        57
#            1     0.7000    0.6901    0.6950        71
#
#     accuracy                         0.6641       128
#    macro avg     0.6603    0.6609    0.6606       128
# weighted avg     0.6647    0.6641    0.6643       128

# %%
x = X0[["3PA","3P%","percent_from_3"]]
y = X0["Playoff"]

x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.3, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.5517241379310345
# precision: 0.59375
# recall: 0.59375
# f1_score: 0.59375
#               precision    recall  f1-score   support
#
#            0     0.5000    0.5000    0.5000        52
#            1     0.5938    0.5938    0.5938        64
#
#     accuracy                         0.5517       116
#    macro avg     0.5469    0.5469    0.5469       116
# weighted avg     0.5517    0.5517    0.5517       116

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# ###2 Point Shooting vs Playoffs (2014-2022)

# %%
x = X1[["2PA","2P%","percent_from_2"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.5777777777777777
# precision: 0.5135135135135135
# recall: 0.95
# f1_score: 0.6666666666666667
#               precision    recall  f1-score   support
#
#            0     0.8750    0.2800    0.4242        50
#            1     0.5135    0.9500    0.6667        40
#
#     accuracy                         0.5778        90
#    macro avg     0.6943    0.6150    0.5455        90
# weighted avg     0.7143    0.5778    0.5320        90

# %%
x = X1[["2PA","2P%","percent_from_2"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.6333333333333333
# precision: 0.574468085106383
# recall: 0.675
# f1_score: 0.6206896551724138
#               precision    recall  f1-score   support
#
#            0     0.6977    0.6000    0.6452        50
#            1     0.5745    0.6750    0.6207        40
#
#     accuracy                         0.6333        90
#    macro avg     0.6361    0.6375    0.6329        90
# weighted avg     0.6429    0.6333    0.6343        90

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# ###2 Point Shooting vs Playoffs (2001-2013)

# %%
x = X0[["2PA","2P%","percent_from_2"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.671875
# precision: 0.6933333333333334
# recall: 0.7323943661971831
# f1_score: 0.7123287671232877
#               precision    recall  f1-score   support
#
#            0     0.6415    0.5965    0.6182        57
#            1     0.6933    0.7324    0.7123        71
#
#     accuracy                         0.6719       128
#    macro avg     0.6674    0.6644    0.6653       128
# weighted avg     0.6703    0.6719    0.6704       128

# %%
x = X0[["2PA","2P%","percent_from_2"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)
my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.6171875
# precision: 0.6447368421052632
# recall: 0.6901408450704225
# f1_score: 0.6666666666666666
#               precision    recall  f1-score   support
#
#            0     0.5769    0.5263    0.5505        57
#            1     0.6447    0.6901    0.6667        71
#
#     accuracy                         0.6172       128
#    macro avg     0.6108    0.6082    0.6086       128
# weighted avg     0.6145    0.6172    0.6149       128

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 100), 'learning_rate': 'invscaling', 'solver': 'sgd'}
# Best Cross-Validation Score: 0.5502262443438914
# Test Score: 0.5546875

# %% [markdown]
# ###Team Defense vs Playoffs (2014-2022)
#
# ```
# # This is formatted as code
# ```

# %%
x = X1[["DRtg", "Defense Four Factors|eFG%", "Defense Four Factors|TOV%", "Defense Four Factors|DRB%", "Defense Four Factors|FT/FGA"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.6888888888888889
# precision: 0.6153846153846154
# recall: 0.8
# f1_score: 0.6956521739130435
#               precision    recall  f1-score   support
#
#            0     0.7895    0.6000    0.6818        50
#            1     0.6154    0.8000    0.6957        40
#
#     accuracy                         0.6889        90
#    macro avg     0.7024    0.7000    0.6887        90
# weighted avg     0.7121    0.6889    0.6880        90

# %%
x = X1[["DRtg", "Defense Four Factors|eFG%", "Defense Four Factors|TOV%", "Defense Four Factors|DRB%", "Defense Four Factors|FT/FGA"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.6333333333333333
# precision: 0.5714285714285714
# recall: 0.7
# f1_score: 0.6292134831460674
#               precision    recall  f1-score   support
#
#            0     0.7073    0.5800    0.6374        50
#            1     0.5714    0.7000    0.6292        40
#
#     accuracy                         0.6333        90
#    macro avg     0.6394    0.6400    0.6333        90
# weighted avg     0.6469    0.6333    0.6337        90

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# ###Team Defense vs Playoffs (2001-2013)

# %%
x = X0[["DRtg", "Defense Four Factors|eFG%", "Defense Four Factors|TOV%", "Defense Four Factors|DRB%", "Defense Four Factors|FT/FGA"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.7734375
# precision: 0.8
# recall: 0.7887323943661971
# f1_score: 0.7943262411347518
#               precision    recall  f1-score   support
#
#            0     0.7414    0.7544    0.7478        57
#            1     0.8000    0.7887    0.7943        71
#
#     accuracy                         0.7734       128
#    macro avg     0.7707    0.7716    0.7711       128
# weighted avg     0.7739    0.7734    0.7736       128

# %%
x = X0[["DRtg", "Defense Four Factors|eFG%", "Defense Four Factors|TOV%", "Defense Four Factors|DRB%", "Defense Four Factors|FT/FGA"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.7421875
# precision: 0.7714285714285715
# recall: 0.7605633802816901
# f1_score: 0.7659574468085106
#               precision    recall  f1-score   support
#
#            0     0.7069    0.7193    0.7130        57
#            1     0.7714    0.7606    0.7660        71
#
#     accuracy                         0.7422       128
#    macro avg     0.7392    0.7399    0.7395       128
# weighted avg     0.7427    0.7422    0.7424       128

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best Parameters: {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'solver': 'sgd'}
# Best Cross-Validation Score: 0.8177224736048265
# Test Score: 0.7734375

# %% [markdown]
# ###Team Offense vs Playoffs (2014-2022)

# %%
x = X1[["ORtg","Offense Four Factors|eFG%","Offense Four Factors|TOV%","Offense Four Factors|ORB%","Offense Four Factors|FT/FGA"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.7111111111111111
# precision: 0.6458333333333334
# recall: 0.775
# f1_score: 0.7045454545454546
#               precision    recall  f1-score   support
#
#            0     0.7857    0.6600    0.7174        50
#            1     0.6458    0.7750    0.7045        40
#
#     accuracy                         0.7111        90
#    macro avg     0.7158    0.7175    0.7110        90
# weighted avg     0.7235    0.7111    0.7117        90

# %%
x = X1[["ORtg","Offense Four Factors|eFG%","Offense Four Factors|TOV%","Offense Four Factors|ORB%","Offense Four Factors|FT/FGA"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.6444444444444445
# precision: 0.5833333333333334
# recall: 0.7
# f1_score: 0.6363636363636365
#               precision    recall  f1-score   support
#
#            0     0.7143    0.6000    0.6522        50
#            1     0.5833    0.7000    0.6364        40
#
#     accuracy                         0.6444        90
#    macro avg     0.6488    0.6500    0.6443        90
# weighted avg     0.6561    0.6444    0.6451        90

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# ###Team Offense vs Playoffs (2001-2013)

# %%
x = X0[["ORtg","Offense Four Factors|eFG%","Offense Four Factors|TOV%","Offense Four Factors|ORB%","Offense Four Factors|FT/FGA"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.7109375
# precision: 0.7236842105263158
# recall: 0.7746478873239436
# f1_score: 0.7482993197278911
#               precision    recall  f1-score   support
#
#            0     0.6923    0.6316    0.6606        57
#            1     0.7237    0.7746    0.7483        71
#
#     accuracy                         0.7109       128
#    macro avg     0.7080    0.7031    0.7044       128
# weighted avg     0.7097    0.7109    0.7092       128

# %%
x = X0[["ORtg","Offense Four Factors|eFG%","Offense Four Factors|TOV%","Offense Four Factors|ORB%","Offense Four Factors|FT/FGA"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.6171875
# precision: 0.6486486486486487
# recall: 0.676056338028169
# f1_score: 0.6620689655172414
#               precision    recall  f1-score   support
#
#            0     0.5741    0.5439    0.5586        57
#            1     0.6486    0.6761    0.6621        71
#
#     accuracy                         0.6172       128
#    macro avg     0.6114    0.6100    0.6103       128
# weighted avg     0.6154    0.6172    0.6160       128

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Best Parameters: {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'solver': 'sgd'}
# Best Cross-Validation Score: 0.6392156862745098
# Test Score: 0.671875

# %% [markdown]
# ###Team Dominance vs Playoffs (2014-2022)

# %%
x = X1[["SRS", "MOV"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.8666666666666667
# precision: 0.8333333333333334
# recall: 0.875
# f1_score: 0.8536585365853658
#               precision    recall  f1-score   support
#
#            0     0.8958    0.8600    0.8776        50
#            1     0.8333    0.8750    0.8537        40
#
#     accuracy                         0.8667        90
#    macro avg     0.8646    0.8675    0.8656        90
# weighted avg     0.8681    0.8667    0.8669        90

# %%
x = X1[["SRS", "MOV"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.8666666666666667
# precision: 0.868421052631579
# recall: 0.825
# f1_score: 0.8461538461538461
#               precision    recall  f1-score   support
#
#            0     0.8654    0.9000    0.8824        50
#            1     0.8684    0.8250    0.8462        40
#
#     accuracy                         0.8667        90
#    macro avg     0.8669    0.8625    0.8643        90
# weighted avg     0.8667    0.8667    0.8663        90

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# ###Team Dominance vs Playoffs (2001-2013)

# %%
x = X0[["SRS", "MOV"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.953125
# precision: 0.9333333333333333
# recall: 0.9859154929577465
# f1_score: 0.9589041095890412
#               precision    recall  f1-score   support
#
#            0     0.9811    0.9123    0.9455        57
#            1     0.9333    0.9859    0.9589        71
#
#     accuracy                         0.9531       128
#    macro avg     0.9572    0.9491    0.9522       128
# weighted avg     0.9546    0.9531    0.9529       128

# %%
x = X0[["SRS", "MOV"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.8984375
# precision: 0.881578947368421
# recall: 0.9436619718309859
# f1_score: 0.9115646258503401
#               precision    recall  f1-score   support
#
#            0     0.9231    0.8421    0.8807        57
#            1     0.8816    0.9437    0.9116        71
#
#     accuracy                         0.8984       128
#    macro avg     0.9023    0.8929    0.8961       128
# weighted avg     0.9001    0.8984    0.8978       128

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# ###Experience vs Playoffs (2014-2022)

# %%
x = X1[["count_playoff_games", "L1YP","L3YP","L6YP"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 1.0
# precision: 1.0
# recall: 1.0
# f1_score: 1.0
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        50
#            1     1.0000    1.0000    1.0000        40
#
#     accuracy                         1.0000        90
#    macro avg     1.0000    1.0000    1.0000        90
# weighted avg     1.0000    1.0000    1.0000        90

# %%
x = X1[["count_playoff_games", "L1YP","L3YP","L6YP"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 1.0
# precision: 1.0
# recall: 1.0
# f1_score: 1.0
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        50
#            1     1.0000    1.0000    1.0000        40
#
#     accuracy                         1.0000        90
#    macro avg     1.0000    1.0000    1.0000        90
# weighted avg     1.0000    1.0000    1.0000        90

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# ### Experience vs Playoffs (2001-2013)

# %%
x = X0[["count_playoff_games", "L1YP","L3YP","L6YP"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 1.0
# precision: 1.0
# recall: 1.0
# f1_score: 1.0
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        57
#            1     1.0000    1.0000    1.0000        71
#
#     accuracy                         1.0000       128
#    macro avg     1.0000    1.0000    1.0000       128
# weighted avg     1.0000    1.0000    1.0000       128

# %%
x = X0[["count_playoff_games", "L1YP","L3YP","L6YP"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 1.0
# precision: 1.0
# recall: 1.0
# f1_score: 1.0
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000        57
#            1     1.0000    1.0000    1.0000        71
#
#     accuracy                         1.0000       128
#    macro avg     1.0000    1.0000    1.0000       128
# weighted avg     1.0000    1.0000    1.0000       128

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# Starpower vs Playoffs (2014-2022)
#
# ```
# # This is formatted as code
# ```

# %%
x = X1[["sum_dpoy_shares","sum_mvp_shares","count_all_defensive", "count_all_nba"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.9222222222222223
# precision: 1.0
# recall: 0.825
# f1_score: 0.9041095890410958
#               precision    recall  f1-score   support
#
#            0     0.8772    1.0000    0.9346        50
#            1     1.0000    0.8250    0.9041        40
#
#     accuracy                         0.9222        90
#    macro avg     0.9386    0.9125    0.9193        90
# weighted avg     0.9318    0.9222    0.9210        90

# %%
x = X1[["sum_dpoy_shares","sum_mvp_shares","count_all_defensive", "count_all_nba"]]
y = X1["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.9888888888888889
# precision: 1.0
# recall: 0.975
# f1_score: 0.9873417721518987
#               precision    recall  f1-score   support
#
#            0     0.9804    1.0000    0.9901        50
#            1     1.0000    0.9750    0.9873        40
#
#     accuracy                         0.9889        90
#    macro avg     0.9902    0.9875    0.9887        90
# weighted avg     0.9891    0.9889    0.9889        90

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# Starpower vs Playoffs (2001-2013)

# %%
x = X0[["sum_dpoy_shares","sum_mvp_shares","count_all_defensive", "count_all_nba"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

logreg_model = LogisticRegression()

logreg_model.fit(x_train, y_train)

y_pred = logreg_model.predict(x_test)

print("accuracy:",accuracy_score(y_test,y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# accuracy: 0.9375
# precision: 1.0
# recall: 0.8873239436619719
# f1_score: 0.9402985074626865
#               precision    recall  f1-score   support
#
#            0     0.8769    1.0000    0.9344        57
#            1     1.0000    0.8873    0.9403        71
#
#     accuracy                         0.9375       128
#    macro avg     0.9385    0.9437    0.9374       128
# weighted avg     0.9452    0.9375    0.9377       128

# %%
x = X0[["sum_dpoy_shares","sum_mvp_shares","count_all_defensive", "count_all_nba"]]
y = X0["Playoff"]
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.33, random_state=42)

my_classifier = AdaBoostClassifier(n_estimators=50,
                         learning_rate=1)

my_model = my_classifier.fit(x_train, y_train)

y_pred = my_model.predict(x_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("precision:",precision_score(y_test,y_pred))
print("recall:",recall_score(y_test,y_pred))
print("f1_score:",f1_score(y_test,y_pred))
print(classification_report(y_test,y_pred,digits=4))
# Out:
# Accuracy: 0.984375
# precision: 1.0
# recall: 0.971830985915493
# f1_score: 0.9857142857142858
#               precision    recall  f1-score   support
#
#            0     0.9661    1.0000    0.9828        57
#            1     1.0000    0.9718    0.9857        71
#
#     accuracy                         0.9844       128
#    macro avg     0.9831    0.9859    0.9842       128
# weighted avg     0.9849    0.9844    0.9844       128

# %%
# Define hyperparameter grid
param_grid = {
    'hidden_layer_sizes': [(50), (100), (50, 50), (100,100), (50,1), (100,1), (1),(3),(5),(7),(11),(13),(3,3),(5,5),(7,7),(9,9),(11,11),(13,13),(1,1),(3,1),(5,1),(7,1),(9,1),(11,1),(13,1)],
    'activation': ['relu', 'tanh'],
    'solver': ['adam', 'sgd'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate': ['constant', 'invscaling', 'adaptive']
}

# Create MLPClassifier and GridSearchCV
mlp = MLPClassifier(max_iter=1000)  # You can set other relevant parameters here
grid_search = GridSearchCV(mlp, param_grid, cv=5)

# Fit GridSearchCV
grid_search.fit(x_train, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Evaluate on test data
best_model = grid_search.best_estimator_
test_score = best_model.score(x_test, y_test)

print("Best Parameters:", best_params)
print("Best Cross-Validation Score:", best_score)
print("Test Score:", test_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
